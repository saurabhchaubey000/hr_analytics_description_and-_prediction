# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"D:\harry bhai\pandas and numpy\HR_comma_sep.csv")

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
data.shape   # How many records
# Out:
# (14999, 10)

# %%
data.columns  # total 10 variables are there
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
#now we describe our data by which we can easy find out the idea of distribution of data 
data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
#to describe all term we use attribute include=all(unique, top ,frequency)
#benifit of include all are we can also find out the frquency of string variables(columns),
#to know more we have to convert our string variable into boolen or numbers by using get.dummies or label encoder.

data.describe(include='all')

#in this destribution table we can find out min,max,25%(1 quartile),75%(3 quartile),mean or median (depend on data).  
#it is 5n which we use for findig outlier by using whisker plot or IQR
# Out:
#         satisfaction_level  last_evaluation  number_project  \
# count         14999.000000     14999.000000    14999.000000
# unique                 NaN              NaN             NaN
# top                    NaN              NaN             NaN
# freq                   NaN              NaN             NaN
# mean              0.612834         0.716102        3.803054
# std               0.248631         0.171169        1.232592
# min               0.090000         0.360000        2.000000
# 25%               0.440000         0.560000        3.000000
# 50%               0.640000         0.720000        4.000000
# 75%               0.820000         0.870000        5.000000
# max               1.000000         1.000000        7.000000
#
#         average_montly_hours  time_spend_company  Work_accident          left  \
# count           14999.000000        14999.000000   14999.000000  14999.000000
# unique                   NaN                 NaN            NaN           NaN
# ...

# %%
#How many variables are available and formats

data.info()

# there are 10 variables

# two of then are in float 64'
# two of them are in object/string.
# six of them are int64.
# float64(2), int64(6), object(2).
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# Department               14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
#now we check our distribution by using matplotlib
# we are only be able to see hist for int or float variables for string/object variable we need to convert it n boolen or number.
data.hist(figsize=(10,10))

#time spend company= right sckewness
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000D08EF28>,
# ...
#       dtype=object)

# %%
#now we use pairplot of seaborn to see the 
#bivariate analysis

sns.pairplot(data)

#in below pair plot we are not finding any highly postive corellation graph.

# %%
data1=data.corr()
#bivariate analysis
# we have seen below we dont have any high positive corellation all are neutral or negative so we dont remove any columns.
data1
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
# now we see corelation by using heat map(categorical plot) of seaborn

sns.heatmap(data1,annot=True,center=True)

# %%
data2=data.cov()
#bivariate analysis
data2
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               0.061817         0.004469       -0.043814
# last_evaluation                  0.004469         0.029299        0.073703
# number_project                  -0.043814         0.073703        1.519284
# average_montly_hours            -0.248945         2.904356       25.683271
# time_spend_company              -0.036618         0.032888        0.354166
# Work_accident                    0.005133        -0.000428       -0.002055
# left                            -0.041128         0.000479        0.012488
# promotion_last_5years            0.000919        -0.000214       -0.001078
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.248945           -0.036618
# last_evaluation                    2.904356            0.032888
# number_project                    25.683271            0.354166
# ...

# %%
sns.heatmap(data2,annot=True,center=True)

# %%
#invalid or missing value
data.isnull().count()
# Out:
# satisfaction_level       14999
# last_evaluation          14999
# number_project           14999
# average_montly_hours     14999
# time_spend_company       14999
# Work_accident            14999
# left                     14999
# promotion_last_5years    14999
# Department               14999
# salary                   14999
# dtype: int64

# %%
data.isnull().count().sum()
# Out:
# 149990

# %%
data.size
# Out:
# 149990

# %%
# there is no any null value in any column as we seen above that out  data.isnull().count().sum()=data.size.

# %%
# now we convert our object in binomial or number by using label encoder.

from sklearn.preprocessing import LabelEncoder
OBJ=LabelEncoder()
data["Department_new"]=OBJ.fit_transform(data["Department"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Department'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-5890750486f7> in <module>
# ...

# %%
data.drop("Department",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-88c096317a5c> in <module>
# ----> 1 data.drop("Department",axis=1,inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  salary  \
# 0                   3              0     1                      0     low
# 1                   6              0     1                      0  medium
# 2                   4              0     1                      0  medium
# 3                   5              0     1                      0     low
# 4                   3              0     1                      0     low
#
#    Department_new
# 0               7
# 1               7
# ...

# %%
# now we change salary column in number
from sklearn.preprocessing import LabelEncoder
OBJ=LabelEncoder()
data["Salary_new"]=OBJ.fit_transform(data["salary"])

# %%
data.drop("salary",axis=1,inplace=True)

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0
#
#    Department_new  Salary_new
# 0               7           1
# 1               7           2
# ...

# %%
#now we work on outlier we use to differnt method first we draw a boxplot by using seaborn

# %%
sns.boxplot(x=data["average_montly_hours"])

# %%
sns.boxplot(x=data["time_spend_company"])

# %%
sns.boxplot(x=data["last_evaluation"])

# %%
sns.boxplot(x=data["satisfaction_level"])

# %%
#no of project in monthly hour and sallary
sns.boxplot(x=data["number_project"],y=data["average_montly_hours"],hue=data["Salary_new"])

# %%
sns.distplot(data["satisfaction_level"])

# %%
# Summary statistic

#as we have seen it is unsupervised machine learning probleam we dont have outcome in variables.
